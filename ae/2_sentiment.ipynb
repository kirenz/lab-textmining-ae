# %% [markdown]
# # Sentiment Analysis with NLTK

# %% [markdown]
# ## Python setup
#
#
# We need the following modules:
#
# - NLTK
# - Pandas
# - Altair

# %%
import nltk

# we suppress some unimportant warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data import

# %%
import pandas as pd

# Import some prepared twitter data from cnn breaking news
df = pd.read_csv("https://raw.githubusercontent.com/kirenz/datasets/master/sentiment-cnn.csv")

df.head(3)
# Out:
#                                                 text  \
# 0  the body of missing princeton university stude...
# 1  uk prime minister liz truss quits after a disa...
# 2  trump weighs letting federal agents return to ...
#
#                   created_at  \
# 0  2022-10-20 19:58:17+00:00
# 1  2022-10-20 12:37:10+00:00
# 2  2022-10-19 23:03:37+00:00
#
#                                           text_token  \
# 0  ['the', 'body', 'of', 'missing', 'princeton', ...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
#
#                                         text_token_s  \
# 0  ['body', 'missing', 'princeton', 'university',...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
#
#                                              text_si  \
# 0  body missing princeton university student misr...
# 1  prime minister liz truss quits disastrous six ...
# 2  trump weighs letting federal agents return mar...
#
#                                             text_sil
# 0  body missing princeton university student misr...
# 1  prime minister liz truss quits disastrous six ...
# 2  trump weighs letting federal agents return mar...

# %% [markdown]
# ### Data corrections

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          22 non-null     object
#  1   created_at    22 non-null     datetime64[ns, UTC]
#  2   text_token    22 non-null     object
#  3   text_token_s  22 non-null     object
#  4   text_si       22 non-null     object
#  5   text_sil      22 non-null     object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### VADER lexicon

# %% [markdown]
# - NLTK provides a simple rule-based model for general sentiment analysis called VADER, which stands for "Valence Aware Dictionary and Sentiment Reasoner" (Hutto & Gilbert, 2014).

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jankirenz/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ### Sentiment Intensity Analyzer

# %% [markdown]
# - Initialize an object of `SentimentIntensityAnalyzer` with name "analyzer":

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# ### Polarity scores
#
# - Use the `polarity_scores` method:

# %%
df['polarity'] = df['text_sil'].apply(lambda x: analyzer.polarity_scores(x))

# %%
df.head(3)
# Out:
#                                                 text  \
# 0  the body of missing princeton university stude...
# 1  uk prime minister liz truss quits after a disa...
# 2  trump weighs letting federal agents return to ...
#
#                  created_at  \
# 0 2022-10-20 19:58:17+00:00
# 1 2022-10-20 12:37:10+00:00
# 2 2022-10-19 23:03:37+00:00
#
#                                           text_token  \
# 0  ['the', 'body', 'of', 'missing', 'princeton', ...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
#
#                                         text_token_s  \
# 0  ['body', 'missing', 'princeton', 'university',...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
#
#                                              text_si  \
# 0  body missing princeton university student misr...
# 1  prime minister liz truss quits disastrous six ...
# 2  trump weighs letting federal agents return mar...
#
#                                             text_sil  \
# 0  body missing princeton university student misr...
# 1  prime minister liz truss quits disastrous six ...
# 2  trump weighs letting federal agents return mar...
#
#                                             polarity
# 0  {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'comp...
# 1  {'neg': 0.206, 'neu': 0.794, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...

# %% [markdown]
# ### Transform data

# %%
# Change data structure (we unnest the column polarity and add new columns)
df = pd.concat([df.drop(['polarity'], axis=1), df['polarity'].apply(pd.Series)], axis=1)

# %%
df.head()
# Out:
#                                                 text  \
# 0  the body of missing princeton university stude...
# 1  uk prime minister liz truss quits after a disa...
# 2  trump weighs letting federal agents return to ...
# 3  britain's home secretary suella braverman quit...
# 4  russian president vladimir putin signs a decre...
#
#                  created_at  \
# 0 2022-10-20 19:58:17+00:00
# 1 2022-10-20 12:37:10+00:00
# 2 2022-10-19 23:03:37+00:00
# 3 2022-10-19 16:17:29+00:00
# 4 2022-10-19 12:02:15+00:00
#
#                                           text_token  \
# 0  ['the', 'body', 'of', 'missing', 'princeton', ...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
# 3  ['britain', 's', 'home', 'secretary', 'suella'...
# 4  ['russian', 'president', 'vladimir', 'putin', ...
#
#                                         text_token_s  \
# 0  ['body', 'missing', 'princeton', 'university',...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
# 3  ['britain', 'home', 'secretary', 'suella', 'br...
# 4  ['russian', 'president', 'vladimir', 'putin', ...
#
#                                              text_si  \
# 0  body missing princeton university student misr...
# 1  prime minister liz truss quits disastrous six ...
# 2  trump weighs letting federal agents return mar...
# 3  britain home secretary suella braverman quits ...
# 4  russian president vladimir putin signs decree ...
#
#                                             text_sil    neg    neu   pos  \
# 0  body missing princeton university student misr...  0.216  0.784  0.00
# 1  prime minister liz truss quits disastrous six ...  0.206  0.794  0.00
# 2  trump weighs letting federal agents return mar...  0.000  0.860  0.14
# 3  britain home secretary suella braverman quits ...  0.152  0.848  0.00
# 4  russian president vladimir putin signs decree ...  0.000  1.000  0.00
#
#    compound
# 0   -0.2960
# 1   -0.5994
# 2    0.3818
# 3   -0.3612
# 4    0.0000

# %% [markdown]
# Create new variable called sentiment which contains the entries "neutral," "positive" or "negative" (depending on the compound score).
#
#
# Hint:
#
#
# ---
#
# ```python
# df['___'] = df['___'].___(___ x: '___' if ___ >___ else '___' if ___ else '___')
# ```
#
# ---
#
# - Name the new variable `sentiment`
# - Use variable `compound` as basis
# - apply a lambda function to each row.
# - The lambda function should write a name in a cell:
#   - 'positive' `if x>0`
#   - 'neutral' `if x==0`
#   - 'negative' for all other cases (`else`)

# %%
### BEGIN SOLUTION
df['sentiment'] = df['compound'].apply(lambda x: 'positive' if x >0 else 'neutral' if x==0 else 'negative')
### END SOLUTION

# %%
# check your code
assert df.iloc[0, 10] == 'negative'

# %%
df.head()
# Out:
#                                                 text  \
# 0  the body of missing princeton university stude...
# 1  uk prime minister liz truss quits after a disa...
# 2  trump weighs letting federal agents return to ...
# 3  britain's home secretary suella braverman quit...
# 4  russian president vladimir putin signs a decre...
#
#                  created_at  \
# 0 2022-10-20 19:58:17+00:00
# 1 2022-10-20 12:37:10+00:00
# 2 2022-10-19 23:03:37+00:00
# 3 2022-10-19 16:17:29+00:00
# 4 2022-10-19 12:02:15+00:00
#
#                                           text_token  \
# 0  ['the', 'body', 'of', 'missing', 'princeton', ...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
# 3  ['britain', 's', 'home', 'secretary', 'suella'...
# 4  ['russian', 'president', 'vladimir', 'putin', ...
#
#                                         text_token_s  \
# 0  ['body', 'missing', 'princeton', 'university',...
# 1  ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2  ['trump', 'weighs', 'letting', 'federal', 'age...
# 3  ['britain', 'home', 'secretary', 'suella', 'br...
# 4  ['russian', 'president', 'vladimir', 'putin', ...
#
#                                              text_si  \
# 0  body missing princeton university student misr...
# 1  prime minister liz truss quits disastrous six ...
# 2  trump weighs letting federal agents return mar...
# 3  britain home secretary suella braverman quits ...
# 4  russian president vladimir putin signs decree ...
#
#                                             text_sil    neg    neu   pos  \
# 0  body missing princeton university student misr...  0.216  0.784  0.00
# 1  prime minister liz truss quits disastrous six ...  0.206  0.794  0.00
# 2  trump weighs letting federal agents return mar...  0.000  0.860  0.14
# 3  britain home secretary suella braverman quits ...  0.152  0.848  0.00
# 4  russian president vladimir putin signs decree ...  0.000  1.000  0.00
#
#    compound sentiment
# 0   -0.2960  negative
# 1   -0.5994  negative
# 2    0.3818  positive
# 3   -0.3612  negative
# 4    0.0000   neutral

# %% [markdown]
# ### Max and min sentiment

# %%
# Tweet with highest positive sentiment
df[['text', 'compound', 'neg', 'neu', 'pos', 'sentiment']].loc[df['compound'].idxmax()]
# Out:
# text         bruce sutter, a cy young award-winning relief ...
# compound                                                0.8834
# neg                                                      0.126
# neu                                                      0.386
# pos                                                      0.488
# sentiment                                             positive
# Name: 16, dtype: object

# %%
# Tweet with highest negative sentiment 
# ...seems to be a case of wrong classification because of the word "deficit"
df[['text', 'compound', 'neg', 'neu', 'pos', 'sentiment']].loc[df['compound'].idxmin()]
# Out:
# text         jury finds paul flores guilty of first-degree ...
# compound                                               -0.9531
# neg                                                       0.58
# neu                                                      0.337
# pos                                                      0.083
# sentiment                                             negative
# Name: 6, dtype: object

# %% [markdown]
# ### Visualize data

# %%
import altair as alt

# create data to change colors in Altair plot
domain = ['neutral', 'positive', 'negative']
range_=['#b2d8d8',"#008080", '#db3d13']


alt.Chart(df).mark_bar().encode(
    x=alt.X('count()', title=None),
    y=alt.Y('sentiment', sort="-x"),
    color= alt.Color('sentiment', legend=None, scale=alt.Scale(domain=domain, range=range_))
).properties(
    title="Sentiment analysis",
    width=400,
    height=150,
)
# Out:
# alt.Chart(...)

# %%
# Function to add date variables to DataFrame.
def add_date_info(df):
  df['created_at'] = pd.to_datetime(df['created_at'], unit='ns')
  df['Year'] = pd.DatetimeIndex(df['created_at']).year
  df['Month'] = pd.DatetimeIndex(df['created_at']).month
  df['Day'] = pd.DatetimeIndex(df['created_at']).day
  df['DOY'] = pd.DatetimeIndex(df['created_at']).dayofyear
  df['Date'] = pd.DatetimeIndex(df['created_at']).date
  return df

# %%
add_date_info(df)
# Out:
#                                                  text  \
# 0   the body of missing princeton university stude...
# 1   uk prime minister liz truss quits after a disa...
# 2   trump weighs letting federal agents return to ...
# 3   britain's home secretary suella braverman quit...
# 4   russian president vladimir putin signs a decre...
# 5   rising food and housing costs drove uk inflati...
# 6   jury finds paul flores guilty of first-degree ...
# 7   russian expat who was the main source for infa...
# 8   a pilot and passenger are dead after a plane c...
# 9   ukraine's president zelensky says 30% of the c...
# 10  president biden announces the formal launch of...
# 11  a russian fighter jet has crashed into a resid...
# 12  former president donald trump's company charge...
# 13  steve bannon sentencing recommendation seeks s...
# 14  blasts were heard in the ukrainian capital as ...
# 15  authorities in central california have arreste...
# 16  bruce sutter, a cy young award-winning relief ...
# 17  judge throws out one of five charges against i...
# 18  robbie coltrane, the actor who brought to life...
# 19  former president trump has not said whether he...
# 20  kwasi kwarteng has been fired as britain's cha...
# 21  kroger announces it's merging with albertsons ...
#
#                   created_at  \
# 0  2022-10-20 19:58:17+00:00
# 1  2022-10-20 12:37:10+00:00
# 2  2022-10-19 23:03:37+00:00
# 3  2022-10-19 16:17:29+00:00
# 4  2022-10-19 12:02:15+00:00
# 5  2022-10-19 09:04:45+00:00
# 6  2022-10-18 21:35:05+00:00
# 7  2022-10-18 20:29:03+00:00
# 8  2022-10-18 16:00:21+00:00
# 9  2022-10-18 10:33:29+00:00
# 10 2022-10-17 19:27:45+00:00
# 11 2022-10-17 17:27:13+00:00
# 12 2022-10-17 16:31:30+00:00
# 13 2022-10-17 13:08:39+00:00
# 14 2022-10-17 05:12:01+00:00
# 15 2022-10-15 23:48:28+00:00
# 16 2022-10-14 20:06:13+00:00
# 17 2022-10-14 19:39:52+00:00
# 18 2022-10-14 17:30:19+00:00
# 19 2022-10-14 14:52:35+00:00
# 20 2022-10-14 11:44:29+00:00
# 21 2022-10-14 11:40:16+00:00
#
#                                            text_token  \
# 0   ['the', 'body', 'of', 'missing', 'princeton', ...
# 1   ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2   ['trump', 'weighs', 'letting', 'federal', 'age...
# 3   ['britain', 's', 'home', 'secretary', 'suella'...
# 4   ['russian', 'president', 'vladimir', 'putin', ...
# 5   ['rising', 'food', 'and', 'housing', 'costs', ...
# 6   ['jury', 'finds', 'paul', 'flores', 'guilty', ...
# 7   ['russian', 'expat', 'who', 'was', 'the', 'mai...
# 8   ['a', 'pilot', 'and', 'passenger', 'are', 'dea...
# 9   ['ukraine', 's', 'president', 'zelensky', 'say...
# 10  ['president', 'biden', 'announces', 'the', 'fo...
# 11  ['a', 'russian', 'fighter', 'jet', 'has', 'cra...
# 12  ['former', 'president', 'donald', 'trump', 's'...
# 13  ['steve', 'bannon', 'sentencing', 'recommendat...
# 14  ['blasts', 'were', 'heard', 'in', 'the', 'ukra...
# 15  ['authorities', 'in', 'central', 'california',...
# 16  ['bruce', 'sutter', 'a', 'cy', 'young', 'award...
# 17  ['judge', 'throws', 'out', 'one', 'of', 'five'...
# 18  ['robbie', 'coltrane', 'the', 'actor', 'who', ...
# 19  ['former', 'president', 'trump', 'has', 'not',...
# 20  ['kwasi', 'kwarteng', 'has', 'been', 'fired', ...
# 21  ['kroger', 'announces', 'it', 's', 'merging', ...
#
#                                          text_token_s  \
# 0   ['body', 'missing', 'princeton', 'university',...
# 1   ['uk', 'prime', 'minister', 'liz', 'truss', 'q...
# 2   ['trump', 'weighs', 'letting', 'federal', 'age...
# 3   ['britain', 'home', 'secretary', 'suella', 'br...
# 4   ['russian', 'president', 'vladimir', 'putin', ...
# 5   ['rising', 'food', 'housing', 'costs', 'drove'...
# 6   ['jury', 'finds', 'paul', 'flores', 'guilty', ...
# 7   ['russian', 'expat', 'main', 'source', 'infamo...
# 8   ['pilot', 'passenger', 'dead', 'plane', 'crash...
# 9   ['ukraine', 'president', 'zelensky', 'says', '...
# 10  ['president', 'biden', 'announces', 'formal', ...
# 11  ['russian', 'fighter', 'jet', 'crashed', 'resi...
# 12  ['former', 'president', 'donald', 'trump', 'co...
# 13  ['steve', 'bannon', 'sentencing', 'recommendat...
# 14  ['blasts', 'heard', 'ukrainian', 'capital', 'r...
# 15  ['authorities', 'central', 'california', 'arre...
# 16  ['bruce', 'sutter', 'cy', 'young', 'award', 'w...
# 17  ['judge', 'throws', 'one', 'five', 'charges', ...
# 18  ['robbie', 'coltrane', 'actor', 'brought', 'li...
# 19  ['former', 'president', 'trump', 'said', 'whet...
# 20  ['kwasi', 'kwarteng', 'fired', 'britain', 'cha...
# 21  ['kroger', 'announces', 'merging', 'albertsons...
#
#                                               text_si  \
# 0   body missing princeton university student misr...
# 1   prime minister liz truss quits disastrous six ...
# 2   trump weighs letting federal agents return mar...
# 3   britain home secretary suella braverman quits ...
# 4   russian president vladimir putin signs decree ...
# 5   rising food housing costs drove inflation back...
# 6   jury finds paul flores guilty first degree mur...
# 7   russian expat main source infamous trump dossi...
# 8   pilot passenger dead plane crashed car dealers...
# 9   ukraine president zelensky says country power ...
# 10  president biden announces formal launch studen...
# 11  russian fighter jet crashed residential buildi...
# 12  former president donald trump company charged ...
# 13  steve bannon sentencing recommendation seeks s...
# 14  blasts heard ukrainian capital result apparent...
# 15  authorities central california arrested man co...
# 16  bruce sutter young award winning relief pitche...
# 17  judge throws one five charges igor danchenko m...
# 18  robbie coltrane actor brought life lovable gam...
# 19  former president trump said whether comply sub...
# 20  kwasi kwarteng fired britain chancellor weeks ...
# 21  kroger announces merging albertsons billion de...
#
#                                              text_sil    neg    neu    pos  \
# 0   body missing princeton university student misr...  0.216  0.784  0.000
# 1   prime minister liz truss quits disastrous six ...  0.206  0.794  0.000
# 2   trump weighs letting federal agents return mar...  0.000  0.860  0.140
# 3   britain home secretary suella braverman quits ...  0.152  0.848  0.000
# 4   russian president vladimir putin signs decree ...  0.000  1.000  0.000
# 5   rising food housing costs drove inflation back...  0.000  1.000  0.000
# 6   jury finds paul flores guilty first degree mur...  0.580  0.337  0.083
# 7   russian expat main source infamous trump dossi...  0.364  0.445  0.190
# 8   pilot passenger dead plane crashed car dealers...  0.318  0.682  0.000
# 9   ukraine president zelensky says country power ...  0.357  0.643  0.000
# 10  president biden announces formal launch studen...  0.000  0.826  0.174
# 11  russian fighter jet crashed residential buildi...  0.000  0.882  0.118
# 12  former president donald trump company charged ...  0.184  0.816  0.000
# 13  steve bannon sentencing recommendation seeks s...  0.401  0.599  0.000
# 14  blasts heard ukrainian capital result apparent...  0.152  0.848  0.000
# 15  authorities central california arrested man co...  0.409  0.591  0.000
# 16  bruce sutter young award winning relief pitche...  0.126  0.386  0.488
# 17  judge throws one five charges igor danchenko m...  0.096  0.780  0.124
# 18  robbie coltrane actor brought life lovable gam...  0.153  0.678  0.169
# 19  former president trump said whether comply sub...  0.000  1.000  0.000
# 20  kwasi kwarteng fired britain chancellor weeks ...  0.175  0.825  0.000
# 21  kroger announces merging albertsons billion de...  0.000  0.845  0.155
#
#     compound sentiment  Year  Month  Day  DOY        Date
# 0    -0.2960  negative  2022     10   20  293  2022-10-20
# 1    -0.5994  negative  2022     10   20  293  2022-10-20
# 2     0.3818  positive  2022     10   19  292  2022-10-19
# 3    -0.3612  negative  2022     10   19  292  2022-10-19
# 4     0.0000   neutral  2022     10   19  292  2022-10-19
# 5     0.0000   neutral  2022     10   19  292  2022-10-19
# 6    -0.9531  negative  2022     10   18  291  2022-10-18
# 7    -0.6486  negative  2022     10   18  291  2022-10-18
# 8    -0.7906  negative  2022     10   18  291  2022-10-18
# 9    -0.7269  negative  2022     10   18  291  2022-10-18
# 10    0.2732  positive  2022     10   17  290  2022-10-17
# 11    0.1531  positive  2022     10   17  290  2022-10-17
# 12   -0.5426  negative  2022     10   17  290  2022-10-17
# 13   -0.8271  negative  2022     10   17  290  2022-10-17
# 14   -0.3612  negative  2022     10   17  290  2022-10-17
# 15   -0.8225  negative  2022     10   15  288  2022-10-15
# 16    0.8834  positive  2022     10   14  287  2022-10-14
# 17    0.1531  positive  2022     10   14  287  2022-10-14
# 18    0.1027  positive  2022     10   14  287  2022-10-14
# 19    0.0000   neutral  2022     10   14  287  2022-10-14
# 20   -0.5574  negative  2022     10   14  287  2022-10-14
# 21    0.2960  positive  2022     10   14  287  2022-10-14

# %%
# change format
df['Date'] = pd.to_datetime(df['Date'])

# %%
alt.Chart(df).mark_area().encode(
   x=alt.X('Date', axis=alt.Axis(format='%e.%-m.')),
   y=alt.Y('count(sentiment)'),
   color=alt.Color('sentiment', scale=alt.Scale(domain=domain, range=range_))
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_boxplot().encode(
    x=alt.X('sentiment'),
    y=alt.Y('compound'),
    color=alt.Color('sentiment', scale=alt.Scale(domain=domain, range=range_))
).properties(
    width=200,
    height=200
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Literature:
#
# [Hutto, C.J. & Gilbert, E.E. (2014). VADER: A Parsimonious Rule-based Model for
# Sentiment Analysis of Social Media Text. Eighth International Conference on
# Weblogs and Social Media (ICWSM-14). Ann Arbor, MI, June 2014.](https://ojs.aaai.org/index.php/ICWSM/article/view/14550)
